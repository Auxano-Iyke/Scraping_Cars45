# %%
# DATAQUEST PAGE FOR WEB SCRAPING
# https://www.dataquest.io/blog/web-scraping-beautifulsoup/

# %%
import requests
from bs4 import BeautifulSoup

# %%
'''
Get the page from the website and return the first 500 words of text
'''
# url = 'https://buy.cars45.com/cars?filter=&year_from=1980&year_to=2019&page=2'
url = 'https://buy.cars45.com/cars&filter=&year_from=1980&year_to=2019'
response = requests.get(url)
print(response.text[:500])
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#   <!-- Required meta tags -->
#   <meta charset="utf-8">
#   <meta http-equiv="Cache-Control" content="no-cache" />
# <meta http-equiv="Pragma" content="no-cache" />
# <meta http-equiv="Expires" content="0" />
#   <!-- <meta http-equiv="Cache-control" content="public"> -->
#   <!-- <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> -->
#   <meta name="viewport" content="width=device-width, minimum-scale=1.0, maximum-scale=1.0, user-sc

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
'''
Check and find within the soup of text generated by beautifulsoup from the website and return all divs with a class=product_box
'''
indi_car = soup.find_all('div', {'class':"product_box"})

# %%
indi_car[26].find_all('p')
# Out:
# [<p class="text-small car-origion">Nigerian Used</p>,
#  <p class="text-small mb-1">
#  <span class="text-muted">Mileage:</span> <span class="intersemibold"> 223,456 Km</span>
#  </p>,
#  <p class="text-small mb-1">
#  <span class="text-muted">Year:</span> <span class="intersemibold">2004</span>
#  </p>,
#  <p class="text-small mb-1">
#  <span class="text-muted">Car ID:</span> <span class="intersemibold">NG-451561</span>
#  </p>,
#  <p class="text-muted">
#                                                                                  Abuja - SNB
#                                                                                                                          , Abuja
#
#                                        </p>]

# %%
grades = []
car_models = []
car_use_conds = []
prices = []
mileages = []
years = []
car_ids = []
car_locations = []
indi_car_links = []

for each in indi_car:
    car_link = each.a.attrs['href']
    
    grade = each.a.text.strip()
    car_model = each.h4.text.strip()
    car_use_cond = each.find_all('p')[0].text.strip()
    price = each.h5.text.strip()
    mileage = each.find_all('p')[1].text.strip()
    year = each.find_all('p')[2].text.strip()
    car_id = each.find_all('p')[3].text.strip()
    try:
        car_location = each.find_all('p')[4].text.strip()
    except:
        car_location = each.find_all('p')[3].text.strip()
    
    grades.append(grade) 
    car_models.append(car_model) 
    car_use_conds.append(car_use_cond)
    prices.append(price)
    mileages.append(mileage)
    years.append(year)
    car_ids.append(car_id)
    car_locations.append(car_location)
    indi_car_links.append(car_link)

# %%
car_ids
# Out:
# ['Car ID: NG-441662',
#  'Car ID: NG-445897',
#  'Car ID: NG-445833',
#  'Car ID: NG-445684',
#  'Car ID: NG-445621',
#  'Car ID: NG-445844',
#  'Car ID: NG-445785',
#  'Car ID: NG-445836',
#  'Car ID: NG-445864',
#  'Car ID: NG-445841',
#  'Car ID: NG-445750',
#  'Car ID: NG-445849',
#  'Car ID: NG-445386',
#  'Abuja - SNB\n                                                                                                                        , Abuja',
#  'Car ID: NG-445851',
#  'Car ID: NG-445872',
#  'Car ID: NG-445615',
#  'Car ID: NG-445598',
#  'Car ID: NG-445711',
#  'Car ID: NG-445528',
#  'Car ID: NG-445832',
#  'Car ID: NG-445859',
#  'Car ID: NG-445789',
#  'Car ID: NG-445431',
#  'Car ID: NG-445742',
#  'Car ID: NG-445776',
#  'Car ID: NG-445641',
#  'Car ID: NG-445697',
#  'Car ID: NG-445591',
#  'Car ID: NG-445768',
#  'Car ID: NG-445801',
#  'Car ID: NG-445508',
#  'Car ID: NG-445574',
#  'Car ID: NG-445862',
#  'Car ID: NG-445620',
#  'Car ID: NG-445583',
#  'Car ID: NG-445707',
#  'Car ID: NG-445467',
#  'Car ID: NG-445618',
#  'Car ID: NG-445861',
#  'Car ID: NG-445682',
#  'Car ID: NG-445723',
#  'Car ID: NG-445672',
#  'Car ID: NG-445472',
#  'Car ID: NG-445713',
#  'Car ID: NG-445655',
#  'Car ID: NG-445543',
#  'Car ID: NG-445687',
#  'Car ID: NG-445787',
#  'Car ID: NG-445811',
#  'Car ID: NG-445803',
#  'Car ID: NG-445748',
#  'Car ID: NG-445380',
#  'Car ID: NG-445608',
#  'Car ID: NG-445743',
#  'Car ID: NG-445722',
#  'Car ID: NG-445462',
#  'Car ID: NG-445729',
#  'Car ID: NG-445388',
#  'Car ID: NG-445480']

# %%
import pandas as pd

data = pd.read_csv("cars45.csv")

# %%
import pandas as pd

data = pd.read_csv("cars45.csv")
indi_car_links = data.indi_car_link.tolist()
len(indi_car_links)
# Out:
# 4454

# %%
car_types = []
fuel_usages = []
gear_types = []

for each in indi_car_links[100:500]:
    url = each
    response = requests.get(url)
    indi_car_soup = BeautifulSoup(response.text, 'html.parser')


    indi_car = indi_car_soup.find_all('div',{'class' :"row"} )
    
    x = indi_car[2].text
    import re
    pattern = re.compile(r'\s+')
    sentence = re.sub(pattern, '|', x)
    pat = sentence.split('|')
    pat = [line.strip() for line in pat]

    car_type = pat[1]
    fuel_usage = pat[2]
    gear_type = pat[3]
    
    car_types.append(car_type)
    fuel_usages.append(fuel_usage)
    gear_types.append(gear_type)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-73fb55fc884b> in <module>
#      19
#      20     car_type = pat[1]
# ---> 21     fuel_usage = pat[2]
#      22     gear_type = pat[3]
#      23
#
# IndexError: list index out of range

# %%
len(car_types)
# Out:
# 100

# %%
import pandas as pd

some_info_2 = pd.DataFrame({
 "car_type" : car_types,
'fuel_usage' : fuel_usages,
'gear_type' : gear_types, 
                      
})


concated_info = pd.concat([some_info_1,some_info_2], ignore_index=True)

# %%
import pandas as pd

some_info_2 = pd.DataFrame({
 "car_type" : car_types,
'fuel_usage' : fuel_usages,
'gear_type' : gear_types, 
                      
})

print(some_info_1.info())
some_info_1.head(10)
some_info_1.to_csv('some_info_1.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# car_type      100 non-null object
# fuel_usage    100 non-null object
# gear_type     100 non-null object
# dtypes: object(3)
# memory usage: 2.5+ KB
# None

# %%
car_types
# Out:
# ['Hatchback',
#  'Sedan',
#  'Suv',
#  'Suv',
#  'Suv',
#  'Suv',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Suv',
#  'Sedan',
#  'Mpv',
#  'Sedan',
#  'Hatchback',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Pickup',
#  'Suv',
#  'Mpv',
#  'Sedan',
#  'Sedan',
#  'Suv',
#  'Suv',
#  'Suv',
#  'About',
#  'Suv',
#  'Mpv',
#  'Suv',
#  'Suv',
#  'Suv',
#  'Sedan',
#  'Truck',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'About',
#  'Sedan',
#  'Suv',
#  'Mpv',
#  'Suv',
#  'Sedan',
#  'Suv',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Suv',
#  'Sedan',
#  'Hatchback',
#  'Mpv',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Sedan',
#  'Mpv',
#  'Suv',
#  'Mpv',
#  'Sedan']

# %%
pages = [str(i) for i in range(1,76)]

# %%
from time import sleep
from random import randint
from time import time

# %%
grades = []
car_models = []
car_use_conds = []
prices = []
mileages = []
years = []
car_ids = []
car_locations = []
indi_car_links = []


from requests import get
from bs4 import BeautifulSoup
from time import sleep
from random import randint
from time import time;start_time = time()
from IPython.core.display import clear_output
from warnings import warn


pages = [str(i) for i in range(1,76)]

Requests = 0
start_time =time()


'''
Get the page from the website and return the first 500 words of text
'''
for page in pages:

    response = get('https://buy.cars45.com/cars?filter=&year_from=1980&year_to=2019&page=' + page)
    
    # Pause the loop
    sleep(randint(2,15))
    
    # Monitor the request
    Requests += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(Requests,Requests/elapsed_time))
    clear_output(wait=True)
    
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(Requests, response.status_code))
    
    if Requests > 76:
        warn('Number of requests was greater than expected.')
        
    soup = BeautifulSoup(response.text, 'html.parser')

    '''
    Check and find within the soup of text generated by beautifulsoup from the website and return all divs with a class=product_box
    '''
    indi_car = soup.find_all('div', {'class':"product_box"})

    for each in indi_car:
        car_link = each.a.attrs['href']

        grade = each.a.text.strip()
        car_model = each.h4.text.strip()
        car_use_cond = each.find_all('p')[0].text.strip()
        price = each.h5.text.strip()
        mileage = each.find_all('p')[1].text.strip()
        year = each.find_all('p')[2].text.strip()
        car_id = each.find_all('p')[3].text.strip()
        try:
            car_location = each.find_all('p')[4].text.strip()
        except:
            car_location = each.find_all('p')[3].text.strip()

        grades.append(grade) 
        car_models.append(car_model) 
        car_use_conds.append(car_use_cond)
        prices.append(price)
        mileages.append(mileage)
        years.append(year)
        car_ids.append(car_id)
        car_locations.append(car_location)
        indi_car_links.append(car_link)
# Out:
# Request:75; Frequency: 0.08383329364010429 requests/s

# %%
len(car_types)
# Out:
# 3042

# %%
import pandas as pd

data = pd.read_csv("cars45.csv")
indi_car_links = data.indi_car_link.tolist()
len(indi_car_links)
# Out:
# 4454

# %% [markdown]
# ### Run this Tomorrow

# %%
from requests import get
from bs4 import BeautifulSoup
from time import sleep
from random import randint
from time import time
from IPython.core.display import clear_output
from warnings import warn




car_types = []
fuel_usages = []
gear_types = []

counter = 0
Requests = 0
start_time =time()

for each in indi_car_links[1218:1300]:
    # Pause the loop
    sleep(randint(0,2))
    
     # Monitor the request
    Requests += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(Requests,Requests/elapsed_time))
    clear_output(wait=True)
    
    url = each
    response = requests.get(url)
    indi_car_soup = BeautifulSoup(response.text, 'html.parser')


    indi_car = indi_car_soup.find_all('div',{'class' :"row"} )
    
    x = indi_car[2].text
    import re
    pattern = re.compile(r'\s+')
    sentence = re.sub(pattern, '|', x)
    pat = sentence.split('|')
    pat = [line.strip() for line in pat]

    car_type = pat[1]
    try:
        fuel_usage = pat[2]
    except:
        fuel_usage = 'missing'
    try:
        gear_type = pat[3]
    except:
        fuel_usage = 'missing'
    
    car_types.append(car_type)
    fuel_usages.append(fuel_usage)
    gear_types.append(gear_type)
    counter += 1
    print('This is loop number: ' + str(counter))
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     264             # sending a valid response.
# --> 265             raise RemoteDisconnected("Remote end closed connection without"
#     266                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     264             # sending a valid response.
# --> 265             raise RemoteDisconnected("Remote end closed connection without"
#     266                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-12-82644319a961> in <module>
#      30
#      31     url = each
# ---> 32     response = requests.get(url)
#      33     indi_car_soup = BeautifulSoup(response.text, 'html.parser')
#      34
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
len(gear_types)
# Out:
# 0

# %%
import pandas as pd

some_info_2 = pd.DataFrame({
 "car_type" : car_types,
'fuel_usage' : fuel_usages,
'gear_type' : gear_types, 
                      
})
concated_info = pd.read_csv('for_now3.csv')

concated_info = pd.concat([concated_info,some_info_2], ignore_index=True)

# %%
concated_info.to_csv('for_now4.csv',index=False)

# %%
import pandas as pd
concated_info = pd.read_csv('for_now4.csv')
concated_info.shape
# Out:
# (1218, 3)

# %%
import pandas as pd

cars45 = pd.DataFrame({'grade': grades,
'car_model': car_models,
'car_use_cond': car_use_conds,
'price': prices,
'mileage': mileages,
'year':years,
'car_id':car_ids,
'car_location':car_locations,
 "car_type" : car_types,
'fuel_usage' : fuel_usages,
'gear_type' : gear_types, 
'indi_car_link':indi_car_links                       
})

print(cars45.info())
cars45.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4454 entries, 0 to 4453
# Data columns (total 9 columns):
# grade            4454 non-null object
# car_model        4454 non-null object
# car_use_cond     4454 non-null object
# price            4454 non-null object
# mileage          4454 non-null object
# year             4454 non-null object
# car_id           4454 non-null object
# car_location     4454 non-null object
# indi_car_link    4454 non-null object
# dtypes: object(9)
# memory usage: 313.2+ KB
# None
#   grade                car_model   car_use_cond        price  \
# 0     A       Suzuki Baleno 2019            New  ₦ 7,300,000
# 1     E     1997 Volkswagen Golf  Nigerian Used    ₦ 451,000
# 2     C   2008 Toyota Highlander  Nigerian Used  ₦ 3,861,000
# 3     D        1999 Lexus Rx 300  Nigerian Used    ₦ 836,000
# 4     C       2010 Nissan Murano   Foreign Used  ₦ 1,771,000
# 5     E         2003 Honda Pilot  Nigerian Used    ₦ 946,000
# 6     E  2010 Mercedes-Benz E350   Foreign Used  ₦ 3,861,000
# 7     D        2010 Toyota Camry  Nigerian Used  ₦ 1,331,000
# 8     C        2002 Toyota Camry  Nigerian Used  ₦ 1,001,000
# 9     D       2002 Ford Explorer  Nigerian Used    ₦ 451,000
#
#                 mileage        year             car_id  \
# 0        Mileage:  1 Km  Year: 2019  Car ID: NG-441662
# 1        Mileage:  1 Km  Year: 1997  Car ID: NG-445897
# 2  Mileage:  105,087 Km  Year: 2008  Car ID: NG-445833
# 3  Mileage:  110,663 Km  Year: 1999  Car ID: NG-445684
# 4  Mileage:  171,469 Km  Year: 2010  Car ID: NG-445621
# 5  Mileage:  168,436 Km  Year: 2003  Car ID: NG-445844
# 6  Mileage:  124,858 Km  Year: 2010  Car ID: NG-445785
# 7   Mileage:  79,809 Km  Year: 2010  Car ID: NG-445836
# 8  Mileage:  112,517 Km  Year: 2002  Car ID: NG-445864
# 9  Mileage:  150,412 Km  Year: 2002  Car ID: NG-445841
#
#                                         car_location  \
# 0                              SUZUKI Special Centre
# 1  Mainland 2 - SNB\n                            ...
# 2  Mainland 1 - SNB\n                            ...
# 3  Island - SNB\n                                ...
# 4  Island - SNB\n                                ...
# 5  Mainland 2 - SNB\n                            ...
# 6  Mainland 1 - SNB\n                            ...
# 7  Island - SNB\n                                ...
# 8  Mainland 2 - SNB\n                            ...
# 9  Mainland 2 - SNB\n                            ...
#
#                                        indi_car_link
# 0  https://buy.cars45.com/cars/suzuki-baleno-2019...
# 1  https://buy.cars45.com/cars/volkswagen-golf-19...
# 2  https://buy.cars45.com/cars/toyota-highlander-...
# 3  https://buy.cars45.com/cars/lexus-rx-300-1999-...
# 4  https://buy.cars45.com/cars/nissan-murano-2010...
# 5  https://buy.cars45.com/cars/honda-pilot-2003-a...
# 6  https://buy.cars45.com/cars/mercedes-benz-e350...
# 7  https://buy.cars45.com/cars/toyota-camry-2010-...
# 8  https://buy.cars45.com/cars/toyota-camry-2002-...
# 9  https://buy.cars45.com/cars/ford-explorer-2002...

# %%
cars45.to_csv('cars45.csv',index=False)
